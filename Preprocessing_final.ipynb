# %%
# Import NLTK

import nltk
import string
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

nltk.download()

# Convert to lowercase

new_list_lower = []

for x in review_list['Text']:
    text_lower = x.lower()
    new_list_lower.append(text_lower)
    
review_list['Text'] = new_list_lower
    
# Removing Punctuation

new_list_punc= []

for x in review_list['Text']:
    text_p = "".join([char for char in x if char not in string.punctuation])
    new_list_punc.append(text_p)
    
review_list['Text'] = new_list_punc

# Tokenization

new_list_token = []

for x in review_list['Text']:
    words= word_tokenize(x)
    new_list_token.append(words)

review_list['Text'] = new_list_token
    
# Stopword Filtering

stop_words = stopwords.words('english')
new_list_stop= []

for x in review_list['Text']:
    filtered_words = [word for word in x if word not in stop_words]
    new_list_stop.append(filtered_words)

review_list['Text'] = new_list_stop

# Stemming

porter = PorterStemmer()
new_list_stem

for x in review_list['Text']:
    stemmed = [porter.stem(word) for word in filtered_words]
    new_list_stem.append(stemmed)
    
review_list['Text'] = new_list_stem

# Lemmatization 

wordnet_lemmatizer = WordNetLemmatizer()

new_list_lem =[]

for x in review_list['Text']:
     for word in x:
            lem_words = wordnet_lemmatizer.lemmatize(word)
            new_list_lem.append(lem_words)

review_list['Text'] = new_list_lem

# POS Tagging

new_list_pos = []

pos = pos_tag(review_list['Text'])
new_list_pos.append(pos)

review_list['Text'] = new_list_pos
